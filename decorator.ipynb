# %% [markdown]
# **What is a Decorator?**
#
# A decorator is a function that takes another function as a parameter, adds extra behavior, and returns a new function - without modifying the original function directly.
#
# They are commonly used for:
# * Logging
# * Authentication
# * Measuring execution time
# * Access control
# * Caching

# %% [markdown]
# **Implementation**

# %%
def outer(func):
    def inner(*args, **kwargs):
        print("Decorator: start") 
        func(*args, **kwargs)
        print("Decorator: end")
    
    return inner


@outer
def sayHello(name):
    print(f"Hello {name}")

sayHello("Shamim")
# Expected output
# Decorator: start
# Hello Shamim
# Decorator: end
# Out:
# Decorator: start
# Hello Shamim
# Decorator: end

# %% [markdown]
# Write a add function then will always take two integer value and give sum of their absolute value
#
# a =  2, b = 3,  a + b = 5 <br>
# a = -2, b = 3,  a + b = 5 <br>
# a = -2, b = -3, a + b = 5

# %%
def absolute(func):
    def inner(*args, **kwargs):
        new_args = [num if num > 0 else num * -1 for num in args]
        new_kwargs = {key: val if val > 0 else val * -1 for key, val in kwargs}
        result = func(*new_args, **new_kwargs)
        return result
    
    return inner


@absolute
def add(a: int, b: int) -> int:
    return a + b

inputs = [[2, 3], [-2, 3], [-2, -3]]

for a, b in inputs:
    print(add(a, b))
# Out:
# 5
# 5
# 5

# %% [markdown]
# **Logging Decorator**

# %%
import datetime
import time


def custom_log(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        call_at = datetime.datetime.now() 
        print(f"{call_at} calling {func.__name__} with args: {args}, kwargs: {kwargs}") 
        result = func(*args, **kwargs)
        time.sleep(1)
        end = time.time()
        print(f"{func.__name__} executed within {end-start:.5f} seconds and returned {result}")
    return wrapper


@custom_log
def add(a, b):
    return a + b

add(5, 3)
# Out:
# 2025-11-25 19:15:56.928804 calling add with args: (5, 3), kwargs: {}
# add executed within 1.00118 seconds and returned 8

# %% [markdown]
# **Interview Question**
#
# How would you write a decorator to check if a user is authenticated before executing an API handler?

# %% [markdown]
# 1.Generic Python Version

# %%
def require_auth(func):
    def wrapper(user, *args, **kwargs):
        if not user.get("is_authenticated", False):
            raise PermissionError("User not authenticated")
        return func(user, *args, **kwargs)
    return wrapper

@require_auth
def get_profile(user):
    return f"Profile for {user['username']}"

# %%
user1 = {"username": "Shamim", "is_authenticated": True}
user2 = {"username": "Tamim", "is_authenticated": False}

# %%
print(get_profile(user1))
# Out:
# Profile for Shamim

# %%
print(get_profile(user2))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(get_profile(user2))
#
# Cell In[11], line 4, in require_auth.<locals>.wrapper(user, *args, **kwargs)
#       2 def wrapper(user, *args, **kwargs):
#       3     if not user.get("is_authenticated", False):
# ----> 4         raise PermissionError("User not authenticated")
#       5     return func(user, *args, **kwargs)
#
# PermissionError: User not authenticated

# %% [markdown]
# 2.FAST Api style

# %%
from fastapi import HTTPException, status

def require_auth(func):
    def wrapper(user, *args, **kwargs):
        if not user or not user.get("is_authenticated", False):
            raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Not authenticated")
        return func(user, *args, **kwargs)
    return wrapper

@require_auth
def secure_endpoint(user):
    return {"message": f"Welcome {user['username']}"}

# %%
# Usage
print(secure_endpoint({"username": "shamim", "is_authenticated": True}))
# Out:
# {'message': 'Welcome shamim'}

# %%
# Usage
print(secure_endpoint({"username": "shamim", "is_authenticated": False}))
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Usage
# ----> 2 print(secure_endpoint({"username": "shamim", "is_authenticated": False}))
#
# Cell In[18], line 6, in require_auth.<locals>.wrapper(user, *args, **kwargs)
#       4 def wrapper(user, *args, **kwargs):
#       5     if not user or not user.get("is_authenticated", False):
# ----> 6         raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Not authenticated")
#       7     return func(user, *args, **kwargs)
#
# HTTPException: 401: Not authenticated
