# %% [markdown]
# **Author**
#
# Shamim,
# Remote Backend Engineer at Short Circuit Science<br>
# London, UK <br>
# [GitHub](https://github.com/anamulislamshamim) [LinkedIn](https://www.linkedin.com/in/anamul-islam-shamim/)

# %% [markdown]
# **What is a Class?**<br>
# A class in Python is a blue print for creating objects (instances). It defines attributes (data) and methods (behavior) that the objects will have.
#
# **Why use Classes?**<br>
# * Encapsulation: bundle data (attribute) + behavior (method) together.
# * Reusability: define once, create multiple objects.
# * Abstraction: hide complexity behind methods.
# * Inheritance: extend and reuse existing code.
# * Organization: keeps code modular and readable (good for big projects).

# %% [markdown]
# **Class vs Function**
#
# When to use a Function?<br>
# * Stateless operations (input -> output, no memory of past calls).
# * When you need a single behavior without grouping data and behavior.
# * Good for utility/helper logic.

# %%
def calculate_discount_price(price, discount_percent):
    return price - (price * discount_percent / 100)

print(calculate_discount_price(1000, 10))
# Out:
# 900.0

# %% [markdown]
# When to use a Class?<br>
# * When you need to maintain state across multiple method calls.
# * When you want to group data (attribute) + related behavior (method) together.
# * When you're modeling real-world entities (e.g. Book, User, BankAccount)
# * When you want to use OOP features like Inheritance, Polymorphism, and abstraction.

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []
    
    def add_item(self, name, price):
        self.items.append((name, price)) 

    def total(self, discount=0):
        total_price = sum(price for _, price in self.items)
        if discount > 0:
            total_price = calculate_discount_price(total_price, discount)
        
        return total_price

cart = ShoppingCart()
cart.add_item("Laptop", 1200)
cart.add_item("Mouse", 20)

print(cart.total(discount=10))
# Out:
# 1098.0

# %% [markdown]
# "I use functions when I need simple, stateless, one-off operations. I use classes when I need to encapsulate both data and behavior, especially if I need to maintain state, reuse code, or model real-world entities."

# %% [markdown]
# **Let’s build a small expense tracker**
#
# 1.Using only functions

# %%
def add_expense(expenses, amount, category):
    expenses.append((amount, category))

def total_expenses(expenses):
    return sum(price for price, _ in expenses)

def expenses_by_category(expenses, category):
    return sum(price for price, cat in expenses if cat==category)

# Usage
expenses = []
add_expense(expenses, 100, "Food")
add_expense(expenses, 50, "Transport")
add_expense(expenses, 200, "Food")

print("Total:", total_expenses(expenses))
print("Food expenses:", expenses_by_category(expenses, "Food"))
# Out:
# Total: 350
# Food expenses: 300

# %% [markdown]
# * ✅ Works fine for small programs.
# * ❌ But as the app grows:
# * We’re passing expenses everywhere.
# * Harder to maintain.
# * No encapsulation.
#
# 2.Implement using class

# %%
class ExpenseTracker:
    def __init__(self):
        self.expenses = []
    
    def add_expense(self, price, category):
        self.expenses.append((price, category))
    
    def total_expenses(self):
        return sum(price for price, _ in self.expenses)

    def expenses_by_category(self, category):
        return sum(price for price, cat in self.expenses if cat==category)


# Usage
tracker = ExpenseTracker()
tracker.add_expense(100, "Food")
tracker.add_expense(50, "Transport")
tracker.add_expense(200, "Food")

print("Total:", tracker.total_expenses())
print("Food expenses:", tracker.expenses_by_category("Food"))
# Out:
# Total: 350
# Food expenses: 300

# %% [markdown]
# * ✅ Cleaner.
# * ✅ No need to pass expenses around — it’s part of the object’s state.
# * ✅ Easier to extend (e.g., export to CSV, set monthly budget, etc.).
#
# **🎯 Interview takeaway**
# * 👉 "We usually start with functions when requirements are small, but when we see that multiple functions share and manipulate the same data, that’s a signal to refactor into a class. The class encapsulates state and behavior, making the system easier to maintain and extend."

# %% [markdown]
# **Encapsulation**<br>
# Encapsulation means binding data (attributes) + behavior (method).
#
# **Key Benefits of Encapsulation**<br>
# * Data Protection: Internal state (_balance, _fuel_level) is
# * protected from direct modification
# * Controlled Access: Changes can only happen through defined behaviors (methods)
# * Validation: Methods can validate inputs before modifying data
# * Maintainability: Internal implementation can change without affecting external code
# * Abstraction: Users don't need to know how it works internally, just what it can do

# %% [markdown]
# **Bank Account Class**<br>
# In this class we will apply encapsulation by binding attributes (data) + behavior (method) together.

# %%
import datetime

class BackAccount:
    # class level attributes (data) shared by all instances.
    _total_accounts_created = 0
    _bank_name = "Shamim Bank"
    _customers = {}

    def __init__(self, account_holder, initial_balance=0):
        # Data (attributes) - encapsulated within class
        self.account_holder = account_holder
        self.account_number = self._generate_account_number()
        # protected data attribute
        self._balance = initial_balance
        self._transaction_history = []
        self._add_transaction(f"{datetime.datetime.now()} Account created with initial balance: ${initial_balance}")
        self._add_customer(self.account_number, account_holder)

    @classmethod
    def _add_customer(cls, id, name):
        cls._total_accounts_created += 1
        cls._customers[id] = {"name": name}
    
    @classmethod
    def get_customers(cls):
        return cls._customers
    
    @classmethod
    def from_string(cls, account_data):
        """
        Behavior: Class level method, alternative constructor
        for creating account from string 'name:balance'
        """
        name, balance = account_data.split(":")
        return cls(name, int(balance))

    # class level method
    @classmethod
    def get_total_account(cls):
        return cls._total_accounts_created
    
    @classmethod
    def get_bank_name(cls):
        return cls._bank_name

    @classmethod
    def set_bank_name(cls, name):
        cls._bank_name = name
    
    # Static method: does not need class or instance
    @staticmethod
    def _generate_account_number():
        """
        Generate a random account number (doesn't need class/instance state)
        """
        import uuid
        for _ in range(3):
            acc_id = f"ACC{str(uuid.uuid4())[:8]}"
            if acc_id not in BackAccount._customers:
                return acc_id
        raise ValueError("Failed to generate unique account id.")
        
    
    @staticmethod
    def validate_balance(amount):
        return isinstance(amount, (int, float)) and (amount > 0 and amount < 1_00_000)
    
    # Behavior: Method that operate on the Data (attributes)
    def deposit(self, amount):
        """Behavior: add money to the account""" 
        if self.validate_balance(amount):
            self._balance += amount 
            self._add_transaction(f"{datetime.datetime.now()} Deposited: ${amount}")
            return f"Deposited ${amount}. New balance: ${self._balance}" 
        return "Deposit amount must be positive"

    def withdraw(self, amount):
        """Behavior: Withdraw money from the account"""
        if self.validate_balance(amount):
            if amount <= self._balance:
                self._balance -= amount 
                self._add_transaction(f"{datetime.datetime.now()} Withdrawed: ${amount}")
                return f"Withdrew ${amount}. New balance: ${self._balance}"
        return "Invalid amount: insufficient balance or negative input"

    def transfer(self, amount, target_account):
        if self.withdraw(amount).startswith("Withdrew"):
            target_account.deposit(amount)
            self._add_transaction(f"{datetime.datetime.now()} Transferred: ${amount} to {target_account.account_holder}")
            return f"Transferred ${amount} to {target_account.account_holder}"
        return "Transfer failed!"

    @property
    def get_transaction_history(self):
        """Behavior: View transaction history"""
        # return copy of history list to prevent 
        # modification (security)
        return self._transaction_history.copy()

    # private method
    def _add_transaction(self, description):
        """
        Private behavior: Internal method (behavior) for 
        transaction tracking.
        """
        self._transaction_history.append(description)

    # Dunder method for default string representation
    def __str__(self):
        return f"BankAccount(holder: {self.account_holder}, balance: ${self._balance})"


account1 = BackAccount.from_string("Alice:1000")
account2 = BackAccount("SHAMIM", 150)

print(account1.deposit(250))
print(account1.withdraw(80))
print(account1.transfer(180, account2))
histories = account1.get_transaction_history
for history in histories:
    print(history)

customers = BackAccount.get_customers()
for customer in customers:
    print(f"{customer}: {customers[customer]}")
# Out:
# Deposited $250. New balance: $1250
# Withdrew $80. New balance: $1170
# Transferred $180 to SHAMIM
# 2025-11-28 03:37:03.282944 Account created with initial balance: $1000
# 2025-11-28 03:37:03.283236 Deposited: $250
# 2025-11-28 03:37:03.285347 Withdrawed: $80
# 2025-11-28 03:37:03.285540 Withdrawed: $180
# 2025-11-28 03:37:03.285572 Transferred: $180 to SHAMIM
# ACC1dbdd69a: {'name': 'Alice'}
# ACCfab8fd35: {'name': 'SHAMIM'}

# %% [markdown]
# **Abstraction**<br>
# Abstraction in Object-Oriented Programming (OOP) is the concept of hiding the complex implementation details and only showing the essential features or necessary information to the user.
#
# **🧐 Key Ideas of Abstraction**
# * Focus on 'What' over 'How': It focuses on what an object does rather than how it achieves it.
# * Simplification: It helps manage complexity by presenting a clear, simplified interface.
# * Hiding Complexity: The internal, complicated logic is hidden from the outside world.
#
#
# In Python, abstraction is often achieved using abstract classes and abstract methods defined in the built-in `abc` (Abstract Base Classes) module. An abstract method is declared but contains no implementation, forcing subclasses to provide their own specific implementation.

# %%
from abc import ABC, abstractmethod

# 1. Define the Abstract Base Class (Abstraction)
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        """
        This method is declared but not implemented.
        It forces all the sub-classes to define how
        their engine starts.
        """
        pass

    def drive(self):
        """
        A concrete method that uses the abstract method
        internally or represent a common function.
        """
        print("Vehicle is moving forward...")

# 2. Subclass 1: Specific Implementation of the Abstraction
class Car(Vehicle):
    def start_engine(self):
        print("Car engine started with a key turn.")
    
    def car_model(self):
        print("Porsche-911")


# Usage 
my_car = Car()
my_car.car_model()
my_car.start_engine()
# Out:
# Porsche-911
# Car engine started with a key turn.

# %% [markdown]
# You can not use abstract class directly to create instance of it. But you can inherit all the attribute (data) and behavior (methods).

# %%
my_vehicle = Vehicle()
# will raise error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_vehicle = Vehicle()
#       2 # will raise error
#
# TypeError: Can't instantiate abstract class Vehicle without an implementation for abstract method 'start_engine'

# %% [markdown]
# **Polymorphism**<br>
# Polymorphism means "Many Forms". It allows objects of different classes to be treated as objects of a common superclass, and each can respond to the same method call in their own way.

# %%
from abc import ABC, abstractmethod
from datetime import datetime

# Abstract Base Class (define the interface)
class PaymentMethod(ABC):
    @abstractmethod
    def process_payment(self):
        pass 

    @abstractmethod
    def get_receipt(self):
        pass


# Different implementations (many forms)
class MasterCard(PaymentMethod):
    def __init__(self, card_number, expire_date):
        self.card_number = card_number
        self.expire_date = expire_date
        self.name = "Master Card"

    def process_payment(self, amount):
        # Simulate Master Card processing
        print(f"Processing ${amount} via Master Card {self.card_number[-4:]}")
        return f"CC_REF_{datetime.now().timestamp()}"

    def get_receipt(self):
        return f"Master Card Payment - Card: ****{self.card_number[-4:]}"


class PayPal(PaymentMethod):
    def __init__(self, email):
        self.name = "PayPal"
        self.email = email 
    
    def process_payment(self, amount):
        # Simulate PayPal processing
        print(f"Processing ${amount} via PayPal ({self.email})")
        return f"PP_REF_{datetime.now().timestamp()}" 
    
    def get_receipt(self):
        return f"PayPal Payment - Email: {self.email}"
        
    
# Poly-morphic function - works with any payment method
def handle_payment(payment_method, amount):
    """Process payment without knowing the specific type"""
    print(f"=== Processing {payment_method.name} Payment ===")
    reference = payment_method.process_payment(amount)
    receipt = payment_method.get_receipt()
    
    print(f"Reference: {reference}")
    print(f"Receipt: {receipt}")
    print("Payment completed successfully!\n")

# %%
master_card = MasterCard("4111111111111111", "12/25")
paypal = PayPal("user@example.com")

# Same function call, different behavior
handle_payment(master_card, 100.50)
handle_payment(paypal, 75.25)
# Out:
# === Processing Master Card Payment ===
# Processing $100.5 via Master Card 1111
# Reference: CC_REF_1764344763.054391
# Receipt: Master Card Payment - Card: ****1111
# Payment completed successfully!
#
# === Processing PayPal Payment ===
# Processing $75.25 via PayPal (user@example.com)
# Reference: PP_REF_1764344763.054682
# Receipt: PayPal Payment - Email: user@example.com
# Payment completed successfully!

# %% [markdown]
# Do you see process_payment and get_receipt functions are same in every class but behave differently (many forms) are exactly what polymorphism means!

# %% [markdown]
# **Inheritance**<br>
#
# Inheritance is a mechanism in which a new class (called the subclass or child class) derives properties and behaviors (methods and attributes) from an existing class (called the superclass or parent class).
#
# The main goal is to promote code reusability and establish a natural 'is-a' relationship between objects.
#
# Let's say there are two classes "Vehicle" and "Car". So, naturally Car is a Vehicle right? Do you see `is a` relationship?

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, model, color):
        self.model = model 
        self.color = color 
    
    @property
    def get_model(self):
        print(self.model)
    @property
    def get_color(self):
        print(self.color)

    @abstractmethod
    def start(self):
        pass 

    @abstractmethod
    def oil(self):
        pass 

class BMW(Vehicle):
    def start(self):
        print("Turn on using remote key!")
    
    def oil(self):
        print("Disel Engine")

class Audi(Vehicle):
    def start(self):
        print("Turn on using key and push start!")
    
    def oil(self):
        print("Patrol Engine!")

# Usage 
bmw = BMW("BMW-M4", "Black")
audi = Audi("Audi-A6-family-sedan", "Silver")

bmw.get_model
bmw.get_color
bmw.start()
bmw.oil()

audi.get_model
bmw.get_color
audi.color
audi.start()
audi.oil()
# Out:
# BMW-M4
# Black
# Turn on using remote key!
# Disel Engine
# Audi-A6-family-sedan
# Black
# Turn on using key and push start!
# Patrol Engine!

# %% [markdown]
# **Multiple Inheritance**
#
# You can inherits from class in a single sub-class.

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name 
        self.salary = salary 
    
    def get_salary_info(self):
        return f"{self.name}'s salary: ${self.salary}"


class Developer:
    def __init__(self, position, programming_languages):
        self.position = position 
        self.programmnig_languages = programming_languages

    def code(self):
        return f"Writing code in {','.join(self.programmnig_languages)}"


class Manager:
    def __init__(self, team_size):
        self.team_size = team_size
    
    def manage(self):
        return f"Managing team of {self.team_size} peoples."


class TechLead(Employee, Developer, Manager):
    def __init__(self, name, position, salary, languages, team_size):
        # Initiate all parent classes
        Employee.__init__(self, name, salary)
        Developer.__init__(self, position, languages)
        Manager.__init__(self, team_size)
    
    def lead(self):
        return f"{self.name} is leading technical projects."

# %%
# Usage
tech_lead = TechLead("Shamim", "Backend Engineer", 70_200, ["Python", "Go", "Java"], 10)

print("Shamim is a", tech_lead.position)
print(tech_lead.get_salary_info())
print(tech_lead.code())
print(tech_lead.manage())
print(tech_lead.lead())
# Out:
# Shamim is a Backend Engineer
# Shamim's salary: $70200
# Writing code in Python,Go,Java
# Managing team of 10 peoples.
# Shamim is leading technical projects.

# %% [markdown]
# **Mixin**
#
# A mixin is a special kind of class in object-oriented programming that provides specific functionality to other classes through inheritance, but is not meant to be instantiated on its own.
#
# **Key Characteristics of Mixins:**
# * Purpose-Specific Functionality: Mixin classes provide a single, focused piece of functionality that can be reused across multiple unrelated classes.
#
# * Not Standalone Classes: Mixins are not designed to be instantiated directly - they're meant to be inherited from.
#
# * No Hierarchical Relationship: Unlike traditional inheritance where there's an "is-a" relationship, mixins provide a "has-the-capability-of" relationship.

# %%
class LoggingMixin:
    def log(self, message):
        print(f"[{self.__class__.__name__}] {message}")

class TaskProcessor(LoggingMixin):
    """
    Represents a component that processes tasks and uses LoggingMixin
    to record its operations.
    """
    def __init__(self, task_name):
        self.task_name = task_name
        # Use the inherited 'log' method during initialization
        self.log(f"Initialized processor for task: '{self.task_name}'.")

    def run_task(self):
        self.log("Starting task execution...")
        # Simulate some processing logic
        try:
            result = 100 / 5  # Example calculation
            self.log(f"Task completed successfully. Result: {result}")
            return result
        except ZeroDivisionError as e:
            self.log(f"Error encountered: {e}")
            return None


class NetworkManager(LoggingMixin):
    def connect(self):
        self.log("Attempting network connection...")

# %% [markdown]
# * Avoiding Multiple Inheritance Complexity
# * Mixins are simpler than complex inheritance hierarchies.
# * Modular Design
# * Each mixin handles one specific concern (Single Responsibility Principle).

# %%
# When we create an instance, the log message is immediately printed.
processor = TaskProcessor("Data Cleanup") 

print("\n--- Running the Task ---")
processor.run_task()

manager = NetworkManager()
manager.connect()
# Out:
# [TaskProcessor] Initialized processor for task: 'Data Cleanup'.
#
# --- Running the Task ---
# [TaskProcessor] Starting task execution...
# [TaskProcessor] Task completed successfully. Result: 20.0
# [NetworkManager] Attempting network connection...

# %%
class SaveToFileMixin:
    def save_to_file(self, filename):
        with open(filename, 'w') as file:
            file.write(str(self)) # Relies on __str__ of child class


class MyClass(SaveToFileMixin):
    def __init__(self, data):
        self.data = data 
    
    def __str__(self):
        return f"Data from __str__: {self.data}"

# %%
obj = MyClass("Test data for testing how mixin works")
obj.save_to_file("mixin_output.txt")
